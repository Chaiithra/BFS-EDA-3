# %%
# !pip install opendatasets
# Out:
# Requirement already satisfied: opendatasets in c:\users\hp\anaconda3\lib\site-packages (0.1.22)
# Requirement already satisfied: click in c:\users\hp\anaconda3\lib\site-packages (from opendatasets) (8.0.4)
# Requirement already satisfied: kaggle in c:\users\hp\anaconda3\lib\site-packages (from opendatasets) (1.5.13)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\lib\site-packages (from opendatasets) (4.64.1)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from click->opendatasets) (0.4.6)
# Requirement already satisfied: python-slugify in c:\users\hp\anaconda3\lib\site-packages (from kaggle->opendatasets) (5.0.2)
# Requirement already satisfied: urllib3 in c:\users\hp\anaconda3\lib\site-packages (from kaggle->opendatasets) (1.26.14)
# Requirement already satisfied: python-dateutil in c:\users\hp\anaconda3\lib\site-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: six>=1.10 in c:\users\hp\anaconda3\lib\site-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: certifi in c:\users\hp\anaconda3\lib\site-packages (from kaggle->opendatasets) (2022.12.7)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (from kaggle->opendatasets) (2.28.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\hp\anaconda3\lib\site-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests->kaggle->opendatasets) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests->kaggle->opendatasets) (2.0.4)

# %%
import opendatasets as od

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\Finale\DS ML\jupyter\PracticeRandom\BFS\train.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# 2                      NaN                 NaN      1422
# 3                     14.0                 NaN      1057
# 4                      NaN                 NaN      7969
# ...                    ...                 ...       ...
# 550063                 NaN                 NaN       368
# 550064                 NaN                 NaN       371
# 550065                 NaN                 NaN       137
# 550066                 NaN                 NaN       365
# 550067                 NaN                 NaN       490
#
# [550068 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df.dropna().isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
del df['Product_Category_3']

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Purchase
# 0                 NaN      8370
# 1                 6.0     15200
# 2                 NaN      1422
# 3                14.0      1057
# 4                 NaN      7969

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Purchase'],
#       dtype='object')

# %%
for i in df.columns:
    print(i,df[i].nunique())
# Out:
# User_ID 5891
# Product_ID 3631
# Gender 2
# Age 7
# Occupation 21
# City_Category 3
# Stay_In_Current_City_Years 5
# Marital_Status 2
# Product_Category_1 20
# Product_Category_2 17
# Purchase 18105

# %%
a=len(df[df['Gender'] == 'M'])

# %%
b=len(df[df['Gender'] == 'F'])

# %%
data= pd.DataFrame({'Ratio' : [a,b]},index=['Male','Female'])

# %%
data
# Out:
#          Ratio
# Male    414259
# Female  135809

# %%
data.plot.pie(y='Ratio',figsize=(6,6),autopct="%.2f")
# Out:
# <Axes: ylabel='Ratio'>

# %%
df.groupby('Gender').size().plot(kind='pie',autopct="%.2f",title='Gender Ratio',figsize=(6,6))
# Out:
# <Axes: title={'center': 'Gender Ratio'}>

# %%
df.groupby('Gender').size().plot(kind='bar',
                                xlabel='Gender',
                                 ylabel='Frequency',
                                 title='Gender Ratio',
                                 figsize=(6,6))
# Out:
# <Axes: title={'center': 'Gender Ratio'}, xlabel='Gender', ylabel='Frequency'>

# %%
df.groupby('Gender').sum()['Purchase'].plot(kind='pie',autopct='%.2f')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18528\502006041.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Gender').sum()['Purchase'].plot(kind='pie',autopct='%.2f')
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Gender').mean()['Purchase'].plot(kind='pie',autopct='%.2f')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18528\3030894650.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Gender').mean()['Purchase'].plot(kind='pie',autopct='%.2f')
# <Axes: ylabel='Purchase'>

# %%
 df.groupby('Age').size().plot(kind='bar',figsize=(6,6),title='Purchase Distribution by Age')
# Out:
# <Axes: title={'center': 'Purchase Distribution by Age'}, xlabel='Age'>

# %%
for i in df['Age'].unique():
    print(i)
# Out:
# 0-17
# 55+
# 26-35
# 46-50
# 51-55
# 36-45
# 18-25

# %%
lst=[]
for i in df['Age'].unique():
    
    lst.append((i,df[df['Age']==i]['Product_ID'].nunique()))

data= pd.DataFrame(lst,columns=['Age','No. Of Products'])
data
# Out:
#      Age  No. Of Products
# 0   0-17             2323
# 1    55+             2584
# 2  26-35             3427
# 3  46-50             3106
# 4  51-55             2887
# 5  36-45             3328
# 6  18-25             3220

# %%
data.plot.bar(x='Age',figsize=(8,6))
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby('Age').sum()['Purchase'].plot(kind='bar',figsize=(12,6),title='Amount spent by age')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18528\2195821300.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').sum()['Purchase'].plot(kind='bar',figsize=(12,6),title='Amount spent by age')
# <Axes: title={'center': 'Amount spent by age'}, xlabel='Age'>

# %%
df.groupby('Marital_Status').size().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %%
df.groupby('Gender').size().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Age',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Gender',hue='Age',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Age',hue='Marital_Status',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x=df['City_Category'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x='City_Category',data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category').sum()['Purchase'].plot(kind='pie',autopct='%.2f')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18528\1359040361.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('City_Category').sum()['Purchase'].plot(kind='pie',autopct='%.2f')
# <Axes: ylabel='Purchase'>

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').size().plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: >

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind='bar')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18528\4105308664.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind='bar')
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x=df['Occupation'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>
